# %% [markdown]
# ### **Relatório de Análise**
#
# **Autor:** Pedro Magalhães
# **Data:** 26 de Setembro de 2025
#
# ---
#
# #### **1. Sumário Executivo**
#
# Este relatório apresenta uma análise detalhada dos contratos e das participações em consórcios, realizada como parte de um estudo baseado em dados extraídos e visualizados em cinco abordagens distintas. As principais descobertas do estudo indicam que, embora a esfera estadual seja a que registra o maior número de contratos, a esfera federal se destaca pelo maior valor médio por contrato. Foi observado também um aumento significativo no volume de contratos durante os anos de 2020 e 2021, coincidindo com o período da pandemia de Covid-19, além de um novo pico em 2024, provavelmente influenciado por eventos como as enchentes no Rio Grande do Sul e emergências de saúde pública. O estudo identificou as cinco empresas com maior participação em consórcios, além dos serviços mais e menos contratados. Por fim, foram destacados os cinco maiores contratos em âmbito global e os cinco maiores contratos por empresa.
#
# ---
#
# #### **2. Introdução**
#
# **2.1. Contexto:** Este estudo foi realizado com o objetivo principal de aplicar e praticar técnicas de análise de dados. A análise se concentra em um conjunto de dados sobre contratos e consórcios, buscando compreender padrões de contratação, identificar os principais atores do mercado e extrair tendências temporais.
#
# **2.2. Objetivos:**
# * Analisar a distribuição de contratos e seus valores entre as esferas governamentais (Federal, Estadual, Municipal).
# * Identificar tendências e sazonalidades na assinatura de contratos ao longo dos anos e meses.
# * Determinar as empresas com participações mais ativas em consórcios.
# * Listar os contratos de maior valor, tanto globalmente quanto por empresa.
#
# ---
#
# #### **3. Metodologia**
#
# A análise foi conduzida utilizando-se de técnicas de exploração e visualização de dados, com os resultados consolidados em cinco notebooks Jupyter (`insights1vs.ipynb` a `insights5vs.ipynb`). Foram utilizados gráficos para comparar volumes, valores e identificar tendências.
#
# ---
#
# #### **4. Resultados e Análise**
#
# **4.1. Análise de Contratos por Esfera Governamental**
# * **Volume de Contratos:** A esfera **Estadual** foi a que mais realizou contratos, indicando um volume maior de oportunidades nesse nível.
#
# ![image-3.png](attachment:image-3.png)
#
# * **Valor Médio dos Contratos:** Em contrapartida, a esfera **Federal** apresentou o maior valor médio por contrato, sugerindo projetos de maior porte e orçamento. A esfera Estadual ficou em uma posição intermediária em ambos os quesitos.
#
# ![image-4.png](attachment:image-4.png)
#
# **4.2. Tendências Temporais de Contratação**
# * **Contratos por Ano:** Foi observado um crescimento notável no número de contratos assinados nos anos de **2020 e 2021**, período coincidente com a pandemia de Covid-19, sendo 2021 o ano com o maior pico da série histórica. O ano de **2024** também mostrou um aumento relevante, que pode estar associado a eventos críticos no Brasil, como as enchentes no Rio Grande do Sul e a emergência de saúde relacionada à dengue.
#
# ![image-5.png](attachment:image-5.png)
#
# * **Contratos por Mês:** A análise mensal indicou picos de contratação em determinados períodos, sugerindo a existência de sazonalidade, possivelmente ligada a ciclos orçamentários ou demandas sazonais específicas de cada ano.
#
# **4.3. Empresas com Maior Participação em Consórcios**
# * O estudo identificou as cinco empresas que mais participaram de projetos em consórcio, demonstrando sua forte presença e colaboração no mercado. As empresas líderes foram:
#
# ![image-6.png](attachment:image-6.png)
#
# **4.5. Maiores Contratos por Valor**
# * **Top 5 Contratos Globais:** Foram listados os cinco maiores contratos em valor absoluto, destacando os projetos de maior impacto financeiro na base de dados.
#
# ![image.png](attachment:image.png)
#
# * **Top 5 Contratos por Empresa:** Adicionalmente, a análise detalhou os cinco maiores contratos por empresas, onde podemos ver que todos pertencem ao projeto 'ANGRA3'.
#
# ![image-2.png](attachment:image-2.png)
#
# ---
#
# #### **5. Conclusões e Recomendações**
#
# A análise dos dados proporcionou insights valiosos sobre as dinâmicas do mercado de contratos e consórcios. Foi possível identificar padrões significativos, como o alto volume de negócios na esfera **estadual**, enquanto a esfera **federal** apresenta oportunidades com maior valor financeiro. A relação entre eventos nacionais (como pandemias e desastres naturais) e o aumento de contratos aponta para uma demanda que tende a ser reativa a crises.
#
# **Recomendações:**
#
# * **Foco Estratégico:** Dividir os esforços de prospecção de forma diferenciada: para a esfera **estadual**, focando em volume de contratos, e para a esfera **federal**, buscando oportunidades de maior valor.
# * **Monitoramento de Tendências:** Acompanhar eventos e mudanças no cenário nacional para identificar possíveis picos de demanda, permitindo antecipar necessidades em resposta a crises ou emergências.
# * **Inteligência de Mercado:** Explorar os portfólios das principais empresas do setor de consórcios para identificar potenciais nichos de mercado e possíveis estratégias de colaboração.
# * **Desenvolvimento de Serviços:** Avaliar a oferta de serviços da empresa em função das áreas com maior e menor demanda, para alinhar o portfólio de produtos de forma estratégica.
