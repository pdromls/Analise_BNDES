# %% [markdown]
# # Análise do Banco de Serviços do BNDES
# O objetivo é explorar os contratos de consultoria apoiados pelo BNDES, entendendo sua distribuição por esfera de cliente (federal, estadual, municipal), valores contratados e evolução temporal.

# %% [markdown]
# ----------------------------
# Relembrando inspeção de base
# ----------------------------
#
# # 1. Dimensões (linhas x colunas)
# print("Dimensões:", df.shape)
#
# # 2. Nome das colunas
# print("\nColunas disponíveis:")
# print(df.columns.tolist())
#
# # 3. Tipos de dados de cada coluna
# print("\nTipos de dados:")
# print(df.dtypes)
#
# # 4. Valores ausentes (nulos) por coluna
# print("\nValores nulos por coluna:")
# print(df.isnull().sum())
#
# # 5. Visualizar primeiras linhas
# print("\nPrimeiras linhas da base:")
# display(df.head())
#
# # 6. Visualizar últimas linhas
# print("\nÚltimas linhas da base:")
# display(df.tail())
#
# # 7. Estatísticas descritivas
# print("\nEstatísticas descritivas (colunas numéricas):")
# display(df.describe())
#
# print("\nEstatísticas descritivas (colunas de texto/categoria):")
# display(df.describe(include="object"))

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Conigurações de exibição
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
sns.set(style = 'whitegrid')

# %%
ARQ = '../base_dados/banco-servicos-banco-de-servicos.csv'

# parâmetros de leitura
df = pd.read_csv(
    ARQ,
    sep = ';',
    decimal = ',',
    encoding = 'latin1'
)

# primeiras linhas
df.head()
# Out:
#                      nome_projeto            cliente esfera_cliente  \
# 0               ACRE - SANEAMENTO     ESTADO DO ACRE       Estadual
# 1               ACRE - SANEAMENTO     ESTADO DO ACRE       Estadual
# 2               ACRE - SANEAMENTO     ESTADO DO ACRE       Estadual
# 3  ALAGOAS - SANEAMENTO - BLOCO A  ESTADO DE ALAGOAS       Estadual
# 4  ALAGOAS - SANEAMENTO - BLOCO A  ESTADO DE ALAGOAS       Estadual
#
#      numero_srm numero_ocs data_de_assinatura compartilhado  \
# 0  4.400003e+09  0264/2017         2017-06-14           Não
# 1  4.400003e+09  0264/2017         2017-06-14           Não
# 2  4.400003e+09  0264/2017         2017-06-14           Não
# 3  4.400003e+09  0228/2017         2017-05-30           Sim
# 4  4.400003e+09  0228/2017         2017-05-30           Sim
#
#                                         link_projeto servico_contratado  \
# 0  https://www.bndes.gov.br/arquivos/contratos-ad...      Serviço Único
# 1  https://www.bndes.gov.br/arquivos/contratos-ad...      Serviço Único
# 2  https://www.bndes.gov.br/arquivos/contratos-ad...      Serviço Único
# 3  https://www.bndes.gov.br/arquivos/contratos-ad...      Serviço Único
# 4  https://www.bndes.gov.br/arquivos/contratos-ad...      Serviço Único
#
#                                               objeto  \
# 0  CONTRATAÇÃO DE SERVIÇOS TÉCNICOS ESPECIALIZADO...
# 1  CONTRATAÇÃO DE SERVIÇOS TÉCNICOS ESPECIALIZADO...
# 2  CONTRATAÇÃO DE SERVIÇOS TÉCNICOS ESPECIALIZADO...
# 3                   CONSULTORIA DESESTATIZAÇÃO CASAL
# 4                   CONSULTORIA DESESTATIZAÇÃO CASAL
#
#    valor_global_contrato_reais fim_vigencia  \
# 0                   4049846.93   2021-05-24
# 1                   4049846.93   2021-05-24
# 2                   4049846.93   2021-05-24
# 3                  11069894.62   2022-02-26
# 4                  11069894.62   2022-02-26
#
#                              consorcio      cnpj_consorcio  \
# 0          CONSORCIO SANEAMENTO BRASIL  27.820.864/0001-06
# 1          CONSORCIO SANEAMENTO BRASIL  27.820.864/0001-06
# 2          CONSORCIO SANEAMENTO BRASIL  27.820.864/0001-06
# 3  CONSORCIO EY, FELSBERG, MUZZI E EMA  27.720.709/0001-18
# 4  CONSORCIO EY, FELSBERG, MUZZI E EMA  27.720.709/0001-18
#
#                                              empresa        cnpj_empresa  \
# 0               AVALIAR AVALIACOES E ASSESSORIA LTDA  65.156.739/0001-32
# 1                 ESSE ENGENHARIA E CONSULTORIA LTDA  41.656.372/0001-58
# 2       FIALHO, CANABRAVA, ANDRADE, SALLES ADVOGADOS  02.911.978/0001-30
# 3            E.M.A. ENGENHARIA DE MEIO AMBIENTE LTDA  54.695.317/0001-19
# 4  FELSBERG E PEDRETTI ADVOGADOS E CONSULTORES LE...  09.522.100/0001-52
#
#   lider_consorcio  pp_consorcio
# 0             Não        0.1280
# 1             Não        0.4270
# 2             Sim        0.4450
# 3             Não        0.4605
# 4             Não        0.2064

# %%
print('Dimensões:', df.shape)

df.info()
# Out:
# Dimensões: (910, 18)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 910 entries, 0 to 909
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   nome_projeto                 910 non-null    object
#  1   cliente                      910 non-null    object
#  2   esfera_cliente               910 non-null    object
#  3   numero_srm                   910 non-null    float64
#  4   numero_ocs                   910 non-null    object
#  5   data_de_assinatura           910 non-null    object
#  6   compartilhado                910 non-null    object
#  7   link_projeto                 910 non-null    object
#  8   servico_contratado           910 non-null    object
#  9   objeto                       910 non-null    object
#  10  valor_global_contrato_reais  910 non-null    float64
#  11  fim_vigencia                 910 non-null    object
#  12  consorcio                    910 non-null    object
#  13  cnpj_consorcio               910 non-null    object
#  14  empresa                      910 non-null    object
#  15  cnpj_empresa                 910 non-null    object
#  16  lider_consorcio              910 non-null    object
#  17  pp_consorcio                 910 non-null    float64
# dtypes: float64(3), object(15)
# memory usage: 128.1+ KB

# %%
print(df.isnull().sum())
# Out:
# nome_projeto                   0
# cliente                        0
# esfera_cliente                 0
# numero_srm                     0
# numero_ocs                     0
# data_de_assinatura             0
# compartilhado                  0
# link_projeto                   0
# servico_contratado             0
# objeto                         0
# valor_global_contrato_reais    0
# fim_vigencia                   0
# consorcio                      0
# cnpj_consorcio                 0
# empresa                        0
# cnpj_empresa                   0
# lider_consorcio                0
# pp_consorcio                   0
# dtype: int64

# %%
print(df.describe(include = 'all').T)

# %%
print('\nColunas disponíveis:')
print(df.columns.tolist())
# Out:
# Colunas disponíveis:
# ['nome_projeto', 'cliente', 'esfera_cliente', 'numero_srm', 'numero_ocs', 'data_de_assinatura', 'compartilhado', 'link_projeto', 'servico_contratado', 'objeto', 'valor_global_contrato_reais', 'fim_vigencia', 'consorcio', 'cnpj_consorcio', 'empresa', 'cnpj_empresa', 'lider_consorcio', 'pp_consorcio']

# %%
# Fazendo um tratamento preventivo nas colunas
df.columns = (df.columns
              .str.strip()
              .str.lower()
              .str.replace(' ', '_')
#              .str.replace(r"[^\w]", "", regex=True)
)

print('\nColunas disponíveis:')
print(df.columns.tolist())
# Out:
# Colunas disponíveis:
# ['nome_projeto', 'cliente', 'esfera_cliente', 'numero_srm', 'numero_ocs', 'data_de_assinatura', 'compartilhado', 'link_projeto', 'servico_contratado', 'objeto', 'valor_global_contrato_reais', 'fim_vigencia', 'consorcio', 'cnpj_consorcio', 'empresa', 'cnpj_empresa', 'lider_consorcio', 'pp_consorcio', 'valor_recebido_por_empresa']

# %%
# Tratando dados, fazendo conversão de tipos
# Valor Global Contratado de string para float64
# Data de Assinatura de date para datetime
# Fim Vigência de string para datetime

df['valor_global_contrato_reais'] = pd.to_numeric(df['valor_global_contrato_reais'])

df['data_de_assinatura'] = pd.to_datetime(df['data_de_assinatura'])

df['fim_vigencia'] = pd.to_datetime(df['fim_vigencia'])

# %%
# Verificando a conversão
valor = df.loc[75, 'valor_global_contrato_reais']
print(type(valor))
# Out:
# <class 'numpy.float64'>

# %%
# Descobrindo o valor que cada empresa recebeu por contrato

df['valor_recebido_por_empresa'] = df['valor_global_contrato_reais'] * df['pp_consorcio']
df.head(5)
# Out:
#                      nome_projeto            cliente esfera_cliente  \
# 0               ACRE - SANEAMENTO     ESTADO DO ACRE       Estadual
# 1               ACRE - SANEAMENTO     ESTADO DO ACRE       Estadual
# 2               ACRE - SANEAMENTO     ESTADO DO ACRE       Estadual
# 3  ALAGOAS - SANEAMENTO - BLOCO A  ESTADO DE ALAGOAS       Estadual
# 4  ALAGOAS - SANEAMENTO - BLOCO A  ESTADO DE ALAGOAS       Estadual
#
#      numero_srm numero_ocs data_de_assinatura compartilhado  \
# 0  4.400003e+09  0264/2017         2017-06-14           Não
# 1  4.400003e+09  0264/2017         2017-06-14           Não
# 2  4.400003e+09  0264/2017         2017-06-14           Não
# 3  4.400003e+09  0228/2017         2017-05-30           Sim
# 4  4.400003e+09  0228/2017         2017-05-30           Sim
#
#                                         link_projeto servico_contratado  \
# 0  https://www.bndes.gov.br/arquivos/contratos-ad...      Serviço Único
# 1  https://www.bndes.gov.br/arquivos/contratos-ad...      Serviço Único
# 2  https://www.bndes.gov.br/arquivos/contratos-ad...      Serviço Único
# 3  https://www.bndes.gov.br/arquivos/contratos-ad...      Serviço Único
# 4  https://www.bndes.gov.br/arquivos/contratos-ad...      Serviço Único
#
#                                               objeto  \
# 0  CONTRATAÇÃO DE SERVIÇOS TÉCNICOS ESPECIALIZADO...
# 1  CONTRATAÇÃO DE SERVIÇOS TÉCNICOS ESPECIALIZADO...
# 2  CONTRATAÇÃO DE SERVIÇOS TÉCNICOS ESPECIALIZADO...
# 3                   CONSULTORIA DESESTATIZAÇÃO CASAL
# 4                   CONSULTORIA DESESTATIZAÇÃO CASAL
#
#    valor_global_contrato_reais fim_vigencia  \
# 0                   4049846.93   2021-05-24
# 1                   4049846.93   2021-05-24
# 2                   4049846.93   2021-05-24
# 3                  11069894.62   2022-02-26
# 4                  11069894.62   2022-02-26
#
#                              consorcio      cnpj_consorcio  \
# 0          CONSORCIO SANEAMENTO BRASIL  27.820.864/0001-06
# 1          CONSORCIO SANEAMENTO BRASIL  27.820.864/0001-06
# 2          CONSORCIO SANEAMENTO BRASIL  27.820.864/0001-06
# 3  CONSORCIO EY, FELSBERG, MUZZI E EMA  27.720.709/0001-18
# 4  CONSORCIO EY, FELSBERG, MUZZI E EMA  27.720.709/0001-18
#
#                                              empresa        cnpj_empresa  \
# 0               AVALIAR AVALIACOES E ASSESSORIA LTDA  65.156.739/0001-32
# 1                 ESSE ENGENHARIA E CONSULTORIA LTDA  41.656.372/0001-58
# 2       FIALHO, CANABRAVA, ANDRADE, SALLES ADVOGADOS  02.911.978/0001-30
# 3            E.M.A. ENGENHARIA DE MEIO AMBIENTE LTDA  54.695.317/0001-19
# 4  FELSBERG E PEDRETTI ADVOGADOS E CONSULTORES LE...  09.522.100/0001-52
#
#   lider_consorcio  pp_consorcio  valor_recebido_por_empresa
# 0             Não        0.1280                5.183804e+05
# 1             Não        0.4270                1.729285e+06
# 2             Sim        0.4450                1.802182e+06
# 3             Não        0.4605                5.097686e+06
# 4             Não        0.2064                2.284826e+06

# %%
# Conserto da coluna pp_consorcio, que estava com o a porcentagem de participação no contrato arredondado
pd.set_option('display.float_format', lambda x: '%.4f' % x)

df['pp_consorcio'] = df['pp_consorcio'].round(4)
print(df['pp_consorcio'].tail(20))
# Out:
# 890   0.3500
# 891   0.4000
# 892   0.2000
# 893   0.8000
# 894   0.4225
# 895   0.0423
# 896   0.1690
# 897   0.3662
# 898   0.0633
# 899   0.1964
# 900   0.2792
# 901   0.4611
# 902   0.0633
# 903   0.1964
# 904   0.2792
# 905   0.4611
# 906   0.2433
# 907   0.2433
# 908   0.2433
# 909   0.2701
# Name: pp_consorcio, dtype: float64

# %%
# Escolhendo contratos pelo SRM para fazer um grafico mostrando quanto cada empresa ganhou com aquele contrato

df.tail(1)

# 4400004395.0000
# 4400005441.0000
# 4400003622.0000
# 4400005970.0000
# Out:
#           nome_projeto              cliente esfera_cliente      numero_srm  \
# 909  ZOOLÓGICO DO CIGS  COMANDO DO EXERCITO        Federal 4400005970.0000
#
#     numero_ocs data_de_assinatura compartilhado  \
# 909  0200/2024         2024-07-09           Sim
#
#                                           link_projeto servico_contratado  \
# 909  https://www.bndes.gov.br/arquivos/contratos-ad...      Serviço Único
#
#                                                 objeto  \
# 909  a execução dos SERVIÇOS TÉCNICOS, o que inclui...
#
#      valor_global_contrato_reais fim_vigencia  \
# 909                14750250.0000   2029-06-16
#
#                                      consorcio      cnpj_consorcio  \
# 909  PLANTUC - CONSULTORIA SOCIOAMBIENTAL LTDA  10.417.179/0001-30
#
#                                        empresa        cnpj_empresa  \
# 909  PLANTUC - CONSULTORIA SOCIOAMBIENTAL LTDA  10.417.179/0001-30
#
#     lider_consorcio  pp_consorcio  valor_recebido_por_empresa
# 909             Sim        0.2701                3984042.5250

# %%
num_srm_sel = [4400004395.0000, 4400005441.0000, 4400003622.0000, 4400005970.0000]

df_filtrado = df[df['numero_srm'].isin(num_srm_sel)]
# Out:
#                nome_projeto                 cliente esfera_cliente  \
# 44            CASA DA MOEDA   MINISTERIO DA FAZENDA        Federal
# 45            CASA DA MOEDA   MINISTERIO DA FAZENDA        Federal
# 46            CASA DA MOEDA   MINISTERIO DA FAZENDA        Federal
# 517   PARQUES MG - BIRIBIRI  ESTADO DE MINAS GERAIS       Estadual
# 518   PARQUES MG - BIRIBIRI  ESTADO DE MINAS GERAIS       Estadual
# 519   PARQUES MG - BIRIBIRI  ESTADO DE MINAS GERAIS       Estadual
# 520   PARQUES MG - BIRIBIRI  ESTADO DE MINAS GERAIS       Estadual
# 533  PARQUES MG - RIO PRETO  ESTADO DE MINAS GERAIS       Estadual
# 534  PARQUES MG - RIO PRETO  ESTADO DE MINAS GERAIS       Estadual
# 535  PARQUES MG - RIO PRETO  ESTADO DE MINAS GERAIS       Estadual
#
#          numero_srm numero_ocs data_de_assinatura compartilhado  \
# 44  4400004395.0000  0030/2020         2020-01-24           Não
# 45  4400004395.0000  0030/2020         2020-01-24           Não
# 46  4400004395.0000  0030/2020         2020-01-24           Não
# 517 4400005970.0000  0200/2024         2024-07-09           Sim
# 518 4400005970.0000  0200/2024         2024-07-09           Sim
# 519 4400005970.0000  0200/2024         2024-07-09           Sim
# 520 4400005970.0000  0200/2024         2024-07-09           Sim
# 533 4400005970.0000  0200/2024         2024-07-09           Sim
# 534 4400005970.0000  0200/2024         2024-07-09           Sim
# 535 4400005970.0000  0200/2024         2024-07-09           Sim
#
#                                           link_projeto servico_contratado  \
# 44   https://www.bndes.gov.br/arquivos/contratos-ad...          Serviço B
# 45   https://www.bndes.gov.br/arquivos/contratos-ad...          Serviço B
# 46   https://www.bndes.gov.br/arquivos/contratos-ad...          Serviço B
# 517  https://www.bndes.gov.br/arquivos/contratos-ad...      Serviço Único
# 518  https://www.bndes.gov.br/arquivos/contratos-ad...      Serviço Único
# 519  https://www.bndes.gov.br/arquivos/contratos-ad...      Serviço Único
# 520  https://www.bndes.gov.br/arquivos/contratos-ad...      Serviço Único
# 533  https://www.bndes.gov.br/arquivos/contratos-ad...      Serviço Único
# 534  https://www.bndes.gov.br/arquivos/contratos-ad...      Serviço Único
# 535  https://www.bndes.gov.br/arquivos/contratos-ad...      Serviço Único
#
#                                                 objeto  \
# 44   Contratação de serviços relativos à estruturaç...
# 45   Contratação de serviços relativos à estruturaç...
# 46   Contratação de serviços relativos à estruturaç...
# 517  a execução dos SERVIÇOS TÉCNICOS, o que inclui...
# 518  a execução dos SERVIÇOS TÉCNICOS, o que inclui...
# 519  a execução dos SERVIÇOS TÉCNICOS, o que inclui...
# 520  a execução dos SERVIÇOS TÉCNICOS, o que inclui...
# 533  a execução dos SERVIÇOS TÉCNICOS, o que inclui...
# 534  a execução dos SERVIÇOS TÉCNICOS, o que inclui...
# 535  a execução dos SERVIÇOS TÉCNICOS, o que inclui...
#
#      valor_global_contrato_reais fim_vigencia  \
# 44                  2700000.0000   2023-01-23
# 45                  2700000.0000   2023-01-23
# 46                  2700000.0000   2023-01-23
# 517                14750250.0000   2029-06-16
# 518                14750250.0000   2029-06-16
# 519                14750250.0000   2029-06-16
# 520                14750250.0000   2029-06-16
# 533                14750250.0000   2029-06-16
# 534                14750250.0000   2029-06-16
# 535                14750250.0000   2029-06-16
#
#                                        consorcio      cnpj_consorcio  \
# 44   TAUIL E CHEQUER, G5 E BAKER TILLY CONSORCIO  38.003.065/0001-63
# 45   TAUIL E CHEQUER, G5 E BAKER TILLY CONSORCIO  38.003.065/0001-63
# 46   TAUIL E CHEQUER, G5 E BAKER TILLY CONSORCIO  38.003.065/0001-63
# 517    PLANTUC - CONSULTORIA SOCIOAMBIENTAL LTDA  10.417.179/0001-30
# 518    PLANTUC - CONSULTORIA SOCIOAMBIENTAL LTDA  10.417.179/0001-30
# 519    PLANTUC - CONSULTORIA SOCIOAMBIENTAL LTDA  10.417.179/0001-30
# 520    PLANTUC - CONSULTORIA SOCIOAMBIENTAL LTDA  10.417.179/0001-30
# 533    PLANTUC - CONSULTORIA SOCIOAMBIENTAL LTDA  10.417.179/0001-30
# 534    PLANTUC - CONSULTORIA SOCIOAMBIENTAL LTDA  10.417.179/0001-30
# 535    PLANTUC - CONSULTORIA SOCIOAMBIENTAL LTDA  10.417.179/0001-30
#
#                                            empresa        cnpj_empresa  \
# 44      BAKER TILLY BRASIL GESTAO EMPRESARIAL LTDA  08.580.575/0001-32
# 45   G5 PARTNERS CONSULTORIA E PARTICIPACOES LTDA.  08.696.063/0001-36
# 46                       TAUIL E CHEQUER ADVOGADOS  68.809.318/0001-51
# 517                            PLANTAR IDEIAS LTDA  26.288.600/0001-90
# 518          QUEIROZ, MALUF SOCIEDADE DE ADVOGADOS  19.433.220/0001-37
# 519     VALLYA ADVISORS ASSESSORIA FINANCEIRA LTDA  28.498.811/0001-83
# 520      PLANTUC - CONSULTORIA SOCIOAMBIENTAL LTDA  10.417.179/0001-30
# 533                            PLANTAR IDEIAS LTDA  26.288.600/0001-90
# 534          QUEIROZ, MALUF SOCIEDADE DE ADVOGADOS  19.433.220/0001-37
# 535     VALLYA ADVISORS ASSESSORIA FINANCEIRA LTDA  28.498.811/0001-83
#
#     lider_consorcio  pp_consorcio  valor_recebido_por_empresa
# 44              Não        0.3300                 891000.0000
# 45              Não        0.3300                 891000.0000
# 46              Sim        0.3400                 918000.0000
# 517             Não        0.2433                3588735.8250
# 518             Não        0.2433                3588735.8250
# 519             Não        0.2433                3588735.8250
# 520             Sim        0.2701                3984042.5250
# 533             Não        0.2433                3588735.8250
# 534             Não        0.2433                3588735.8250
# 535             Não        0.2433                3588735.8250

# %%
caminho_arquivo = '../base_dados/dados_filtrados.csv'

df_filtrado.to_csv(caminho_arquivo, index=False)

# %%
df.shape
# Out:
# (910, 19)

# %%
caminho_arquivo = '../base_dados/bd_2.csv'

df.to_csv(caminho_arquivo,
          index=False,
          sep=';',
          decimal=',',
          encoding='latin1')
